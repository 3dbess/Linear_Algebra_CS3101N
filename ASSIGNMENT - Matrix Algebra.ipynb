# %% [markdown]
# #### Bessa Nicole T. Tamarra

# %% [markdown]
# 1. Without the use of any python libraries or modules, develop a function that can perform matrix addition, given two numpy matrices.

# %%
def matrix_addition(matrix1, matrix2):
    # Check if the matrices have the same dimensions
    if len(matrix1) != len(matrix2) or len(matrix1[0]) != len(matrix2[0]):
        raise ValueError("Matrices must have the same dimensions for addition")

    # Initialize an empty result matrix with the same dimensions
    result = [[0] * len(matrix1[0]) for _ in range(len(matrix1))]

    # Perform element-wise addition
    for i in range(len(matrix1)):
        for j in range(len(matrix1[0])):
            result[i][j] = matrix1[i][j] + matrix2[i][j]

    return result

# Example matrices for testing
matrix_a = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
matrix_b = [[9, 8, 7], [6, 5, 4], [3, 2, 1]]

# Test matrix_addition function
result_matrix = matrix_addition(matrix_a, matrix_b)

# Display the result
print("Matrix A:")
for row in matrix_a:
    print(row)

print("\nMatrix B:")
for row in matrix_b:
    print(row)

print("\nResult Matrix:")
for row in result_matrix:
    print(row)
# Out:
# Matrix A:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
#
# Matrix B:
# [9, 8, 7]
# [6, 5, 4]
# [3, 2, 1]
#
# Result Matrix:
# [10, 10, 10]
# [10, 10, 10]
# [10, 10, 10]

# %% [markdown]
# 2. Without the use of any python libraries or modules, develop a function that can multiply two numpy matrices.

# %%
def matrix_multiplication(matrix1, matrix2):
    # Check if the matrices can be multiplied
    if len(matrix1[0]) != len(matrix2):
        raise ValueError("Number of columns in the first matrix must be equal to the number of rows in the second matrix")

    # Initialize an empty result matrix with dimensions (rows of matrix1) x (columns of matrix2)
    result = [[0] * len(matrix2[0]) for _ in range(len(matrix1))]

    # Perform matrix multiplication
    for i in range(len(matrix1)):
        for j in range(len(matrix2[0])):
            for k in range(len(matrix2)):
                result[i][j] += matrix1[i][k] * matrix2[k][j]

    return result

# Example matrices for testing
matrix_a = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
matrix_b = [[9, 8, 7], [6, 5, 4], [3, 2, 1]]

# Test matrix_multiplication function
result_matrix = matrix_multiplication(matrix_a, matrix_b)

# Display the result
print("Matrix A:")
for row in matrix_a:
    print(row)

print("\nMatrix B:")
for row in matrix_b:
    print(row)

print("\nResult Matrix:")
for row in result_matrix:
    print(row)
# Out:
# Matrix A:
# [1, 2, 3]
# [4, 5, 6]
# [7, 8, 9]
#
# Matrix B:
# [9, 8, 7]
# [6, 5, 4]
# [3, 2, 1]
#
# Result Matrix:
# [30, 24, 18]
# [84, 69, 54]
# [138, 114, 90]

# %% [markdown]
# 3. The rule of distributivity states that given two matrices  𝐴 and  𝐵 and a scalar,  𝑘, then  𝑘(𝐴+𝐵)=𝑘𝐴+𝑘𝐵. Instead of writing a proof mathematically, develop two codes for  𝑘(𝐴+𝐵) and  𝑘𝐴+𝑘𝐵.

# %%
def distributive_property_left_scalar(matrix_a, matrix_b, scalar):
    # k(A + B)
    result_left_scalar = [[scalar * (matrix_a[i][j] + matrix_b[i][j]) for j in range(len(matrix_a[0]))] for i in range(len(matrix_a))]
    return result_left_scalar

def distributive_property_right_scalar(matrix_a, scalar):
    # kA
    result_right_scalar_a = [[scalar * matrix_a[i][j] for j in range(len(matrix_a[0]))] for i in range(len(matrix_a))]
    return result_right_scalar_a

def distributive_property_right_scalar_b(matrix_b, scalar):
    # kB
    result_right_scalar_b = [[scalar * matrix_b[i][j] for j in range(len(matrix_b[0]))] for i in range(len(matrix_b))]
    return result_right_scalar_b

# Example matrices for testing
matrix_a = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
matrix_b = [[9, 8, 7], [6, 5, 4], [3, 2, 1]]
scalar = 2

# Test distributive_property_left_scalar function
result_left_scalar = distributive_property_left_scalar(matrix_a, matrix_b, scalar)
print("k(A + B):")
for row in result_left_scalar:
    print(row)

# Test distributive_property_right_scalar function
result_right_scalar_a = distributive_property_right_scalar(matrix_a, scalar)
result_right_scalar_b = distributive_property_right_scalar_b(matrix_b, scalar)
result_right_scalar = matrix_addition(result_right_scalar_a, result_right_scalar_b)

print("\nkA + kB:")
for row in result_right_scalar:
    print(row)
# Out:
# k(A + B):
# [20, 20, 20]
# [20, 20, 20]
# [20, 20, 20]
#
# kA + kB:
# [20, 20, 20]
# [20, 20, 20]
# [20, 20, 20]

# %% [markdown]
# 4. Without using a python library or modules develop a function that can extract the diagonal of a numpy matrix.

# %%
def extract_diagonal(matrix):
    # Check if the matrix is square
    if len(matrix) != len(matrix[0]):
        raise ValueError("Input matrix must be square for diagonal extraction")

    # Extract the diagonal elements
    diagonal = [matrix[i][i] for i in range(len(matrix))]
    return diagonal

# Example matrix for testing
example_matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# Test extract_diagonal function
diagonal_elements = extract_diagonal(example_matrix)
print("Diagonal Elements:")
print(diagonal_elements)
# Out:
# Diagonal Elements:
# [1, 5, 9]

# %% [markdown]
# 5. Without using a python library or modules develop a function that can find a trace of a numpy matrix.

# %%
def matrix_trace(matrix):
    # Check if the matrix is square
    if len(matrix) != len(matrix[0]):
        raise ValueError("Input matrix must be square for trace calculation")

    # Calculate the trace (sum of diagonal elements)
    trace = sum(matrix[i][i] for i in range(len(matrix)))
    return trace

# Example matrix for testing
example_matrix = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# Test matrix_trace function
trace_value = matrix_trace(example_matrix)
print("Trace of the Matrix:", trace_value)
# Out:
# Trace of the Matrix: 15

# %% [markdown]
# ## Problem Solving

# %% [markdown]
# 1. Solve $X$ given that:
# \begin{equation}
# A =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4 \\
# \end{bmatrix},
# B =
# \begin{bmatrix}
# -1 & 0 \\
# 1 & 1 \\
# \end{bmatrix}
# \end{equation}
# - $3X = A-2B$

# %% [markdown]
# \[
# \begin{align*}
# 3X & = A - 2B \\
# X & = \frac{1}{3}(A - 2B) \\
# A - 2B & =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4 \\
# \end{bmatrix}
# -
# 2
# \begin{bmatrix}
# -1 & 0 \\
# 1 & 1 \\
# \end{bmatrix}
# \\
# & =
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4 \\
# \end{bmatrix}
# -
# \begin{bmatrix}
# -2 & 0 \\
# 2 & 2 \\
# \end{bmatrix}
# \\
# & =
# \begin{bmatrix}
# 3 & 2 \\
# 1 & 2 \\
# \end{bmatrix}
# \end{align*}
# \]
# \[
# X = \frac{1}{3}
# \begin{bmatrix}
# 3 & 2 \\
# 1 & 2 \\
# \end{bmatrix}
# \]
# \[
# \boxed{X = \begin{bmatrix} 1 & \frac{2}{3} \\ \frac{1}{3} & \frac{2}{3} \end{bmatrix}}
# \]

# %%
# pythonic solution
import numpy as np

# Define matrices A and B
A = np.array([[1, 2], [3, 4]])
B = np.array([[-1, 0], [1, 1]])

# Compute A - 2B
result = A - 2 * B

# Divide the result by 3 to get X
X = result / 3

# Print the result
print("X =")
print(X)
# Out:
# X =
# [[1.         0.66666667]
#  [0.33333333 0.66666667]]

# %% [markdown]
# - $2(A-B+2X) = 3(X-B)$

# %% [markdown]
# $2A - 2B + 4X = 3X - 3B \\
# 4X - 3X = 2B - 2A - 3B \\
# X = (2B - 2A - 3B) \\
# X = 2
# \begin{bmatrix}
# -1 & 0 \\
# 1 & 1 \\
# \end{bmatrix}
# -
# 2
# \begin{bmatrix}
# 1 & 2 \\
# 3 & 4 \\
# \end{bmatrix}
# -
# 3
# \begin{bmatrix}
# -1 & 0 \\
# 1 & 1 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# -2 & 0 \\
# 2 & 2 \\
# \end{bmatrix}
# -
# \begin{bmatrix}
# 2 & 4 \\
# 6 & 8 \\
# \end{bmatrix}
# -
# \begin{bmatrix}
# -3 & 0 \\
# 3 & 3 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# -2 - 2 + 3 & 0 - 4 - 0 \\
# 2 - 6 - 3 & 2 - 8 - 3 \\
# \end{bmatrix} \\
# \boxed{X =
# \begin{bmatrix}
# -1 & -4 \\
# -7 & -9 \\
# \end{bmatrix}}
# $

# %%
import numpy as np

# Define matrices A and B
A = np.array([[1, 2], [3, 4]])
B = np.array([[-1, 0], [1, 1]])

# Calculate X as described in the equation
X = 2 * B - 2 * A - 3 * B

# Print the result
print("X =")
print(X)
# Out:
# X =
# [[-1 -4]
#  [-7 -9]]

# %% [markdown]
# 2. Write $B$ as a linear combination of the other matrices, if possible.
# -
# \begin{equation}
# A_1 =
# \begin{bmatrix}
# 1 & 2 \\
# -1 & 1 \\
# \end{bmatrix},
# A_2 =
# \begin{bmatrix}
# 0 & 1 \\
# 2 & 1 \\
# \end{bmatrix},
# B =
# \begin{bmatrix}
# 2 & 5 \\
# 0 & 3 \\
# \end{bmatrix}
# \end{equation}
# <br><br>

# %% [markdown]
# \[
# B = c_1A_1 + c_2A_2 \\
# \text{Solving for } c_1 \text{ and } c_2 \text{ via systems of linear equations:} \\
# \begin{align*}
# 2 & = c_1 \cdot 1 + c_2 \cdot 0 \\
# 5 & = c_1 \cdot 2 + c_2 \cdot 1 \\
# 0 & = c_1 \cdot (-1) + c_2 \cdot 2 \\
# 3 & = c_1 \cdot 1 + c_2 \cdot 1 \\
# \end{align*}
# \\
# \text{Eq1: } 2 = c_1 \quad \Rightarrow \quad c_1 = 2 \\
# \text{Eq2: } 5 = 2c_1 + c_2 = 2 \cdot 2 + c_2 \quad \Rightarrow \quad c_2 = -4 \\
# \\
# \boxed{c_1 = 2,\ c_2 = -4} \\
# B = 2A_1 - 4A_2
# \]

# %% [markdown]
# -
# \begin{equation}
# A_1 =
# \begin{bmatrix}
# 1 & 0 \\
# 0 & 1 \\
# \end{bmatrix},
# A_2 =
# \begin{bmatrix}
# 0 & 1 \\
# 1 & 0 \\
# \end{bmatrix},
# A_3 =
# \begin{bmatrix}
# 1 & -1 \\
# 1 & 1 \\
# \end{bmatrix},
# B =
# \begin{bmatrix}
# 2 & 5 \\
# 0 & 3 \\
# \end{bmatrix}
# \end{equation}
# <br>
# <br>

# %% [markdown]
# $B = c_1A_1 + c_2A_2 + c_3A_3 $<br>
# $\text{Solving for $c_1$, $c_2 $ & $c_3$ via systems of linear equations:}$
# $
# 2 = c_1 \cdot 1 + c_2 \cdot 0 + c_3 \cdot 1 \\
# 5 = c_1 \cdot 0 + c_2 \cdot 1 + c_3 \cdot (-1) \\
# 0 = c_1 \cdot 1 + c_2 \cdot 1 + c_3 \cdot 1 \\
# 3 = c_1 \cdot 0 + c_2 \cdot 0 + c_3 \cdot 1
# \\
# Eq1: 2 = c_1 + c_3 \\
# Eq2: 5 = c_2 - c_3 \\
# Eq3: 0 = c_1 + c_2 + c_3 \\
# Eq4: 3 = c_3 \\
# \boxed{2 = c_1 + 3 \quad \Rightarrow \quad c_1 = -1 \\
# 5 = c_2 - 3 \quad \Rightarrow \quad c_2 = 8 \\
# 3 = c_3 \quad \Rightarrow \quad c_3 = 3 \\
# B = -1A_1 + 8A_2 + 3A_3}
# $

# %% [markdown]
# 3. Given the following:
# \begin{equation}
# A =
# \begin{bmatrix}
# 1 & 2 \\
# 2 & 6 \\
# \end{bmatrix},
# b_1 =
# \begin{bmatrix}
# 3 \\
# 5 \\
# \end{bmatrix},
# b_2 =
# \begin{bmatrix}
# -1 \\
# 2 \\
# \end{bmatrix},
# b_3 =
# \begin{bmatrix}
# 2 \\
# 0 \\
# \end{bmatrix}
# \end{equation}
# - Find $A^{-1}$, and use this to solve for $Ax=b_1,Ax=b_2,Ax=b_3$
# - Solve all three linear systems by row reducing the augmented matrix:
# \begin{equation}
# \begin{bmatrix}
# \begin{array}{c|ccc}
# A &
# b_1 &
# b_2 &
# b_3 \\
# \end{array}
# \end{bmatrix}
# \end{equation}

# %% [markdown]
# $A^{-1} = (\frac{1}{det(A)}) *
# \begin{bmatrix}
# d & -b \\
# -c & a \\
# \end{bmatrix} \\
# det(A) = (1 * 6) - (2 * 2) = 6 - 4 = 2 \\
# A^{-1} = (\frac{1}{2}) *
# \begin{bmatrix}
# 6 & -2 \\
# -2 & 1 \\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 3 & -1 \\
# -1 & \frac{1}{2} \\
# \end{bmatrix} \\
# A | b_1 = \begin{bmatrix}\begin{array}{cc|c}
# 1 & 2 & 3 \\
# 2 & 6 & 5 \\
# \end{array}\end{bmatrix}
# \xrightarrow{\text{R}_{2}-2\text{R}_{1}}
# \begin{bmatrix}\begin{array}{cc|c}
# 1 & 2 & 3 \\
# 0 & 2 & -1 \\
# \end{array}\end{bmatrix}
# \xrightarrow{\frac{1}{2}R_2}
# \begin{bmatrix}\begin{array}{cc|c}
# 1 & 2 & 3 \\
# 0 & 1 & -0.5 \\
# \end{array}\end{bmatrix}
# \xrightarrow{\text{R}_{1}-2\text{R}_{2}}
# \begin{bmatrix}\begin{array}{cc|c}
# 1 & 0 & 4 \\
# 0 & 1 & -0.5 \\
# \end{array}\end{bmatrix} \\
# \boxed{A | b_1: x_1 = 4, x_2 = -0.5} \\
# A | b_2 = \begin{bmatrix}\begin{array}{cc|c}
# 1 & 2 & -1 \\
# 2 & 6 & 2 \\
# \end{array}\end{bmatrix}
# \xrightarrow{\text{R}_{2}-2\text{R}_{1}}
# \begin{bmatrix}\begin{array}{cc|c}
# 1 & 2 & -1 \\
# 0 & 2 & 4 \\
# \end{array}\end{bmatrix}
# \xrightarrow{\frac{1}{2}R_2}
# \begin{bmatrix}\begin{array}{cc|c}
# 1 & 2 & -1 \\
# 0 & 1 & 2 \\
# \end{array}\end{bmatrix}
# \xrightarrow{\text{R}_{1}-2\text{R}_{2}}
# \begin{bmatrix}\begin{array}{cc|c}
# 1 & 0 & -5 \\
# 0 & 1 & 2 \\
# \end{array}\end{bmatrix} \\
# \boxed{A | b_2: x_1 = -5, x_2 = 2} \\
# A | b_3 = \begin{bmatrix}\begin{array}{cc|c}
# 1 & 2 & 2 \\
# 2 & 6 & 0 \\
# \end{array}\end{bmatrix}
# \xrightarrow{\text{R}_{2}-2\text{R}_{1}}
# \begin{bmatrix}\begin{array}{cc|c}
# 1 & 2 & 2 \\
# 0 & 2 & -4 \\
# \end{array}\end{bmatrix}
# \xrightarrow{\frac{1}{2}R_2}
# \begin{bmatrix}\begin{array}{cc|c}
# 1 & 2 & 2 \\
# 0 & 1 & -2 \\
# \end{array}\end{bmatrix}
# \xrightarrow{\text{R}_{1}-2\text{R}_{2}}
# \begin{bmatrix}\begin{array}{cc|c}
# 1 & 0 & 6 \\
# 0 & 1 & -2 \\
# \end{array}\end{bmatrix} \\
# \boxed{A | b_3: x_1 = 6, x_2 = -2} \\
# $

# %% [markdown]
# 4. In each given, determine if $b$ is in $col(A)$, and $w$ is in $row(A)$
# -
# \begin{equation}
# A =
# \begin{bmatrix}
# 1 & 0 & -1 \\
# 1 & 1 & 1 \\
# \end{bmatrix},
# b =
# \begin{bmatrix}
# 3 \\
# 2 \\
# \end{bmatrix},
# w =
# \begin{bmatrix}
# -1 &
# 1 &
# 1
# \end{bmatrix},
# \end{equation}

# %% [markdown]
# -
# \begin{equation}
# A =
# \begin{bmatrix}
# 1 & 1 & -1 \\
# 1 & 3 & 0 \\
# 3 & -1 & -5 \\
# \end{bmatrix},
# b =
# \begin{bmatrix}
# 1 \\
# 2 \\
# 1 \\
# \end{bmatrix},
# w =
# \begin{bmatrix}
# 1 &
# -3 &
# -3
# \end{bmatrix},
# \end{equation}

# %% [markdown]
# \begin{align*}
# Ax &= b \\
# \Rightarrow \quad \begin{bmatrix}
# 1 & 1 & -1 \\
# 1 & 3 & 0 \\
# 3 & -1 & -5
# \end{bmatrix}
# \begin{bmatrix}
# x_1 \\
# x_2 \\
# x_3
# \end{bmatrix}
# &= \begin{bmatrix}
# 1 \\
# 2 \\
# 1
# \end{bmatrix} \\
# \Rightarrow \quad \begin{bmatrix}
# x_1 + x_2 - x_3 &= 1 \\
# x_1 + 3x_2 &= 2 \\
# 3x_1 - x_2 - 5x_3 &= 1
# \end{bmatrix}
# \end{align*}
# \begin{align*}
# \\x^T A &= w^T \\
# \Rightarrow \qquad
# \begin{pmatrix}
# x_1 \\
# x_2 \\
# x_3
# \end{pmatrix}^T
# \begin{pmatrix}
# 1 & 1 & -1 \\
# 1 & 3 & 0 \\
# 3 & -1 & -5
# \end{pmatrix}
# &= \begin{pmatrix}
# 1 &
# -3 &
# -3
# \end{pmatrix}^T \\
# \Rightarrow \quad \begin{bmatrix}
# x_1 + 3x_2 - 5x_3 &= 1 \\
# x_1 + x_2 + x_3 &= -3 \\
# -x_1 - x_2 - 3x_3 &= -3
# \end{bmatrix}
# \end{align*}
#
# $\boxed{\text{vector b is in the column space of A, and vector w is in the row space of A}}$

# %% [markdown]
# 5. Find the rank and nullity of:
# \begin{bmatrix}
# 2 & 4 & 0 & 0 & 1 \\
# 6 & 3 & 5 & 1 & 0 \\
# 1 & 0 & 2 & 2 & 5 \\
# 1 & 1 & 1 & 1 & 1 \\
# \end{bmatrix}

# %% [markdown]
# $\begin{bmatrix}
# 2 & 4 & 0 & 0 & 1 \\
# 6 & 3 & 5 & 1 & 0 \\
# 1 & 0 & 2 & 2 & 5 \\
# 1 & 1 & 1 & 1 & 1 \\
# \end{bmatrix}
# \xrightarrow{\text{R}_{2}-3\text{R}_{1}}
# \begin{bmatrix}
# 2 & 4 & 0 & 0 & 1 \\
# 0 & -9 & 5 & 1 & -3 \\
# 1 & 0 & 2 & 2 & 5 \\
# 1 & 1 & 1 & 1 & 1 \\
# \end{bmatrix}
# \xrightarrow{\text{R}_{3}-\frac{1}{2}R_1}
# \begin{bmatrix}
# 2 & 4 & 0 & 0 & 1 \\
# 0 & -9 & 5 & 1 & -3 \\
# 0 & -2 & 2 & 2 & 4 \\
# 1 & 1 & 1 & 1 & 1 \\
# \end{bmatrix}
# \xrightarrow{-\frac{1}{9}R_2}
# \begin{bmatrix}
# 2 & 4 & 0 & 0 & 1 \\
# 0 & 1 & -5/9 & -1/9 & 1/3 \\
# 0 & -2 & 2 & 2 & 4 \\
# 0 & 4.5 & -1.5 & 0.5 & 1.5 \\
# \end{bmatrix}
# \xrightarrow{\text{R}_{3} + 2{R}_{2} \ \text{R}_4 + \frac{9}{2}R_2}
# \begin{bmatrix}
# 2 & 4 & 0 & 0 & 1 \\
# 0 & 1 & -5/9 & -1/9 & 1/3 \\
# 0 & 0 & 4/9 & 4/9 & 10/3 \\
# 0 & 0 & 0 & 0 & 0 \\
# \end{bmatrix} \\
# \boxed{\text{rank of the matrix = 3} \\
#        \text{nullity = # of columns - rank = 2}}
# $
